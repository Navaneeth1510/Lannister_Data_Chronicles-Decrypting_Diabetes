# %%
# data visualisation part

import pandas as pd

file = "C:/Users/NARENDRA/Downloads/The Lannister Data Chronicles_ Decrypting Diabetes.csv"

df = pd.read_csv(file)

dia_positive =df[df['Diabetes_012'] > 0]
dia_negative =df[df['Diabetes_012'] == 0]


print('Positive data frames:')
print(dia_positive.describe())
print("=========================================================================================")
print('Negative data frames:')
print(dia_negative.describe())
# Out:
# Positive data frames:
#        Diabetes_012        HighBP      HighChol     CholCheck           BMI  \
# count  39977.000000  39977.000000  39977.000000  39977.000000  39977.000000
# mean       1.884158      0.738350      0.664407      0.992421     31.802737
# std        0.320039      0.439539      0.472203      0.086730      7.328665
# min        1.000000      0.000000      0.000000      0.000000     13.000000
# 25%        2.000000      0.000000      0.000000      1.000000     27.000000
# 50%        2.000000      1.000000      1.000000      1.000000     31.000000
# 75%        2.000000      1.000000      1.000000      1.000000     35.000000
# max        2.000000      1.000000      1.000000      1.000000     98.000000
#
#              Smoker        Stroke  HeartDiseaseorAttack  PhysActivity  \
# count  39977.000000  39977.000000          39977.000000  39977.000000
# mean       0.515271      0.088376              0.213673      0.636091
# ...
